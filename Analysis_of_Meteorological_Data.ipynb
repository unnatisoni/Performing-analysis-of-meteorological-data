# %% [markdown]
# ### Import the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ANCHAL SONI\Desktop\weatherHistory.csv")

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %% [markdown]
# ### Data Analysis

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.shape
# Out:
# (96453, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %% [markdown]
# ### Dropping the NA values from data

# %%
df=df.dropna()

# %% [markdown]
# ### Unique values in each column

# %%
df.nunique()
# Out:
# Formatted Date              95912
# Summary                        27
# Precip Type                     2
# Temperature (C)              7573
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4971
# Daily Summary                 214
# dtype: int64

# %% [markdown]
# ### Encoding the categorical data

# %%
pre=pd.Categorical(df["Precip Type"]).codes
dai=pd.Categorical(df["Daily Summary"]).codes

# %%
df["Precip Type"]=pre
df["Daily Summary"]=dai

# %%
df.head()
# Out:
#                   Formatted Date        Summary  Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy            0         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy            0         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy            0         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy            0         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy            0         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#    Daily Summary
# 0            197
# 1            197
# 2            197
# 3            197
# 4            197

# %%
df.drop(["Loud Cover"],axis=1,inplace=True)
df.head()
# Out:
#                   Formatted Date        Summary  Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy            0         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy            0         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy            0         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy            0         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy            0         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                   251.0          15.8263               1015.13
# 1                   259.0          15.8263               1015.63
# 2                   204.0          14.9569               1015.94
# 3                   269.0          15.8263               1016.41
# 4                   259.0          15.8263               1016.51
#
#    Daily Summary
# 0            197
# 1            197
# 2            197
# 3            197
# 4            197

# %% [markdown]
# ### Correlation between variables

# %%
df.corr()
# Out:
#                           Precip Type  Temperature (C)  \
# Precip Type                  1.000000        -0.563503
# Temperature (C)             -0.563503         1.000000
# Apparent Temperature (C)    -0.566058         0.992637
# Humidity                     0.232622        -0.632148
# Wind Speed (km/h)           -0.067771         0.008304
# Wind Bearing (degrees)      -0.042142         0.029937
# Visibility (km)             -0.316483         0.393719
# Pressure (millibars)         0.009271        -0.005253
# Daily Summary               -0.251911         0.439386
#
#                           Apparent Temperature (C)  Humidity  \
# Precip Type                              -0.566058  0.232622
# Temperature (C)                           0.992637 -0.632148
# Apparent Temperature (C)                  1.000000 -0.602390
# Humidity                                 -0.602390  1.000000
# Wind Speed (km/h)                        -0.057387 -0.224569
# Wind Bearing (degrees)                    0.028951  0.000814
# Visibility (km)                           0.382589 -0.370511
# Pressure (millibars)                     -0.000037  0.005375
# Daily Summary                             0.434318 -0.368970
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Precip Type                       -0.067771               -0.042142
# Temperature (C)                    0.008304                0.029937
# Apparent Temperature (C)          -0.057387                0.028951
# Humidity                          -0.224569                0.000814
# Wind Speed (km/h)                  1.000000                0.104366
# Wind Bearing (degrees)             0.104366                1.000000
# Visibility (km)                    0.100801                0.048900
# Pressure (millibars)              -0.049453               -0.011629
# Daily Summary                     -0.003597                0.053835
#
#                           Visibility (km)  Pressure (millibars)  Daily Summary
# Precip Type                     -0.316483              0.009271      -0.251911
# Temperature (C)                  0.393719             -0.005253       0.439386
# Apparent Temperature (C)         0.382589             -0.000037       0.434318
# Humidity                        -0.370511              0.005375      -0.368970
# Wind Speed (km/h)                0.100801             -0.049453      -0.003597
# Wind Bearing (degrees)           0.048900             -0.011629       0.053835
# Visibility (km)                  1.000000              0.061011       0.459446
# Pressure (millibars)             0.061011              1.000000       0.054901
# Daily Summary                    0.459446              0.054901       1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr())

# %%
df.drop(["Temperature (C)"],axis=1,inplace=True)

# %%
sns.pairplot(df)

# %% [markdown]
# ### Resample the data

# %%
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'],utc=True)
df = df.set_index('Formatted Date')
data = df[['Apparent Temperature (C)','Humidity']].resample('MS').mean()
data.head()
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625

# %%
import numpy as np
plt.figure(figsize = (10,5))
plt.plot(data['Apparent Temperature (C)'], label = 'april Apparent temp.',color = 'navy', marker = 'o')
plt.title('Variation in Apparent temp. in the month of april',fontsize = 15)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.legend(loc = 0)

# %% [markdown]
# ### Variation of Humidity and Apparent Temperature in the month of April

# %%
april = data[data.index.month==4]
plt.figure(figsize=(15,5))
plt.plot(april.loc['2006-04-01':'2016-04-01', 'Apparent Temperature (C)'], marker='o', linestyle='-',label='Apparent Temperature (C)',color = 'navy');
plt.plot(april.loc['2006-04-01':'2016-04-01', 'Humidity'], marker='o', linestyle='-',label='Humidity',color = 'red');
plt.legend(loc = 'center right',fontsize = 15);
plt.xlabel('Month of April', fontsize = 15);
plt.title('Humidity v/s Apparent Temperature',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Humidity v/s Apparent Temperature')

# %%
plt.figure(figsize=(15,5));
plt.plot(data['Humidity'], label= 'Humidity', color = 'red',linestyle='dashed');
plt.plot(data['Apparent Temperature (C)'], label = 'Apparent temp.',color = 'navy');
plt.title('Variation of Apparent temparature v/s Humidity', fontsize= 25);
plt.legend(loc = 0, fontsize = 12);
plt.xticks(fontsize = 15);
plt.yticks(fontsize = 13);
